# %%
import numpy as np
import pandas as pd
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score
from sklearn.metrics import calinski_harabasz_score, davies_bouldin_score

# %% [markdown]
# # Functions

# %%
def runKmeans_n2(data, score):
    '''
    Runs the k-means for a given cohort with 2 clusters. It predicts the labels of new values and uses the information to get a cutoff.
    It also saves the silhoette coefficient, inertia, calinsiki index and davies index
    Input:
    data (dataframe): HRD results, the rows are different samples and the columns contains information about the sample as well as the the 4 HRD scores
    score (string): Indicates for which score a cutoff should be calculated
    Output:
    results (dictionary): Results contains 5 keys, does are silhouette_coef (average silhouette coefficient), inertia , calinski (Calinski index), davies (Davies index) and n2_cutoff (cutoff value between HRD-high and HRD-low)
    '''
    k = 2
    results = dict()
    
    
    data_hrd = data[score].to_numpy().reshape(-1, 1)
    np.random.seed(42)
    kmeans = KMeans(n_clusters=k, max_iter = 1000)

    # Fit the data to the model
    kmeans.fit(data_hrd)
    
    labels_data = kmeans.predict(data_hrd)
    
    # Get silhouette coefficient
    silhouette_coef = silhouette_score(data_hrd, labels_data)
    inertia = kmeans.inertia_
    
    # Calculate the Calinski-Harabasz index
    calinski_score = calinski_harabasz_score(data_hrd, labels_data)

    # Calculate the Davies-Bouldin index
    davies_score = davies_bouldin_score(data_hrd, labels_data)
    
    # Predict the labels for values between 0 and max(HRDsum)
    max_number = int(max(list(data[score])))
    numbers_vector = np.arange(max_number + 1).reshape(-1, 1)
    labels_numbers = kmeans.predict(numbers_vector).reshape(-1, 1)

    # Find the minimum value for each label
    min_values = [np.min(numbers_vector[labels_numbers == label]) for label in np.unique(labels_numbers)]

    results['silhouette_coef'] = silhouette_coef
    results['inertia'] = inertia
    results['calinski'] = calinski_score
    results['davies'] = davies_score
    results['n2_cutoff'] = int(max(min_values))
    
    return results

def runKmeans_pancancer_n2(data, score):
    '''
    Runs the K-means for each cancer type in the pan cancer cohort with 2 clusters and saves the results in a dataframe
    Input:
    data (dataframe): HRD results, the rows are different samples and the columns contains information about the sample as well as the the 4 HRD scores
    score (string): Indicates for which score a cutoff should be calculated
    Output:
    df (dataframe): Cotains the results from the K-means (columns) for all cohorts (rows). The columns include the total number of cases per cohort and the number of case per type (HRD-high, HRD-low, HRD-medium)
    '''
    
    ## Prepare dataframe
    df = pd.DataFrame(columns=['Project ID','n_cases', 'n2_cutoff', 'n2_silhouette_coef', 'n2_inertia', 'n2_calinski','n2_davies','n2_n_low','n2_n_high'])
    types = np.unique(data['Project ID'])

    for cancer_type in types:
        ## Run K-means
        sub_data = data[data['Project ID'] == cancer_type]
        results = runKmeans_n2(sub_data, score)
        
        ## Extract number of sample per type (high, low)
        n2_cutoff = results['n2_cutoff']
        high = sub_data[sub_data[score]>=n2_cutoff]
        low = sub_data[sub_data[score]<n2_cutoff]

        df.loc[len(df)] = [cancer_type, sub_data.shape[0], n2_cutoff, results['silhouette_coef'], results['inertia'], results['calinski'], results['davies'], high.shape[0],  low.shape[0]]
        
    return df

def runKmeans_n3(data, score):
    '''
    Runs the k-means for a given cohort with 3 clusters. It predicts the labels of new values and uses the information to get a cutoff.
    It also saves the silhoette coefficient, inertia, calinsiki index and davies index
    Input:
    data (dataframe): HRD results, the rows are different samples and the columns contains information about the sample as well as the the 4 HRD scores
    score (string): Indicates for which score a cutoff should be calculated
    Output:
    results (dictionary): Results contains 6 keys, does are silhouette_coef (average silhouette coefficient), inertia , calinski (Calinski index), davies (Davies index) and n3_cutoff_lm (cutoff value between HRD-low and HRD-medium)
    and n3_cutoff_mh (cutoff value between HRD-medium and HRD-high)
    '''    
    k = 3
    results = dict()
    
    
    data_hrd = data[score].to_numpy().reshape(-1, 1)
    np.random.seed(42)
    kmeans = KMeans(n_clusters=k, max_iter = 1000)

    # Fit the data to the model
    kmeans.fit(data_hrd)
    
    labels_data = kmeans.predict(data_hrd)
    
    # Get silhouette coefficient
    silhouette_coef = silhouette_score(data_hrd, labels_data)
    inertia = kmeans.inertia_
    
    # Calculate the Calinski-Harabasz index
    calinski_score = calinski_harabasz_score(data_hrd, labels_data)

    # Calculate the Davies-Bouldin index
    davies_score = davies_bouldin_score(data_hrd, labels_data)
    
    # Predict the labels for values between 0 and max(HRDsum)
    max_number = int(max(list(data[score])))
    numbers_vector = np.arange(max_number + 1).reshape(-1, 1)
    labels_numbers = kmeans.predict(numbers_vector).reshape(-1, 1)

    # Find the minimum value for each label
    min_values = [np.min(numbers_vector[labels_numbers == label]) for label in np.unique(labels_numbers)]
    
    min_values.sort()
    results['silhouette_coef'] = silhouette_coef
    results['inertia'] = inertia
    results['calinski'] = calinski_score
    results['davies'] = davies_score
    results['n3_cutoff_lm'] = int(min_values[-2])
    results['n3_cutoff_mh'] = int(min_values[-1])
    
    return results

def runKmeans_pancancer_n3(data, score):
    '''
    Runs the K-means for each cancer type in the pan cancer cohort with 3 clusters and saves the results in a dataframe
    Input:
    data (dataframe): HRD results, the rows are different samples and the columns contains information about the sample as well as the the 4 HRD scores
    score (string): Indicates for which score a cutoff should be calculated
    Output:
    df (dataframe): Cotains the results from the K-means (columns) for all cohorts (rows). The columns include the total number of cases per cohort and the number of case per type (HRD-high, HRD-low, HRD-medium)
    '''
    
    ## Prepare dataframe
    df = pd.DataFrame(columns=['Project ID','n_cases', 'n3_cutoff_lm','n3_cutoff_mh', 'n3_silhouette_coef', 'n3_inertia', 'n3_calinski', 'n3_davies','n_3_n_high','n3_n_medium','n3_n_low'])
    types = np.unique(data['Project ID'])

    for cancer_type in types:
        
        ## Run K-means
        sub_data = data[data['Project ID'] == cancer_type]
        results = runKmeans_n3(sub_data, score)
        
        ## Extract number of sample per type (high, medium, low)
        cutoff_lm = results['n3_cutoff_lm']
        cutoff_mh = results['n3_cutoff_mh']
        high = sub_data[sub_data[score]>=cutoff_mh]
        low = sub_data[sub_data[score]<cutoff_lm]
        medium = sub_data[(sub_data[score]<cutoff_mh) & (sub_data[score]>=cutoff_lm)]
        df.loc[len(df)] = [cancer_type, sub_data.shape[0], cutoff_lm, cutoff_mh, results['silhouette_coef'], results['inertia'], results['calinski'], results['davies'], high.shape[0], medium.shape[0], low.shape[0]]
        
    return df


def analyseStatistics(data):
    '''
    Function that runs the k-means for all cohorts with 2 to 6 clusters and saves the statsitics (avg. silhouette coef., inertia, calinski index, davies index).
    Input:
    data (dataframe): HRD results, the rows are different samples and the columns contains information about the sample as well as the the 4 HRD scores
    Output:
    df (dataframe): Containg all the results for each cohort for each number of clusters (rows are the different cohorts, columns are the different metrics)
    '''
    
    n_silhoette = [f"n{x}_silhouette" for x in range(2, 7)]
    n_inertia = [f"n{x}_inertia" for x in range(2, 7)]
    n_calinski = [f"n{x}_calinski" for x in range(2, 7)]
    n_davies = [f"n{x}_davies" for x in range(2, 7)]
    
    column_names = ['Project ID'] + n_silhoette + n_inertia + n_calinski + n_davies
    
    df = pd.DataFrame(columns = column_names)
    types = np.unique(data['Project ID'])
    clusters = [2,3,4,5,6]
    
    for cancer_type in types:
        results_type = dict()
        ## Subset data for a single cohort
        sub_data = data[data['Project ID'] == cancer_type]
        data_hrd = sub_data['HRD_sum'].to_numpy().reshape(-1, 1)

        for k in clusters:
            
            ## Runs k-means for n_cluster = 2 to 6 and save the different metrics
            np.random.seed(42)
            kmeans = KMeans(n_clusters=k, max_iter = 1000).fit(data_hrd)
            labels_data = kmeans.predict(data_hrd)
            results_type[str(k)+'_silhouette'] = silhouette_score(data_hrd, labels_data)
            results_type[str(k)+'_inertia'] = kmeans.inertia_
            results_type[str(k)+'_calinski'] = calinski_harabasz_score(data_hrd, labels_data)
            results_type[str(k)+'_davies'] = davies_bouldin_score(data_hrd, labels_data)
            print('Finished analysis for n_comp = '+ str(k) + ' for cohort '+ cancer_type)
        df.loc[len(df)] = [cancer_type] + [results_type[str(k)+'_silhouette'] for k in clusters] + [results_type[str(k)+'_inertia'] for k in clusters] + [results_type[str(k)+'_calinski'] for k in clusters] + [results_type[str(k)+'_davies'] for k in clusters]
        print('Finished cohort '+ cancer_type)
    df.to_csv('../data/kmeans_cluster_analysis.csv', sep=',', header = True)
    
    return df

def loadData(path_data_file):
    '''
    Loads the data and subset it to only extract the primary type.
    Input:
    path_data_file (string): Full path and name of the datafile containing at least the columns (Project ID, HRD_sum, Type)
    Output:
    primary (dataframe): Data containing only the primary sample type
    '''
    HRD_pan_cancer = pd.read_csv(path_data_file, sep=',', header = 0)
    primary = HRD_pan_cancer[HRD_pan_cancer['Type'] == 'Primary']
    primary = primary[primary['Project ID'] != 'TARGET-CCSK']
    
    return primary

def runKmeansCutoff(mode, path_data_file, path_results, score, filename = 'kmeans_cutoff_pancancer'):
    '''
    Runs K-means to infer cutoff.
    Input:
    mode (string): Indicates the number of clusters 'n2' for 2 clusters (low and high), 'n3' for 3 clusters (low, medium, high) or 'both' to get the results for 2 and 3 clusters
    path_data_file (string): Full path and name of the datafile containing at least the columns (Project ID, HRD_sum, Type)
    path_results (string): Path to the folder where the output should be saved
    score (string): Indicates for which score a cutoff should be calculated
    filename (string): Name of the outputfile (default: kmeans_cutoff_pancancer)
    '''
    data = loadData(path_data_file)
    
    if mode == 'n2':
        results_n2 = runKmeans_pancancer_n2(data, score)
        results_n2.to_csv(path_results + '/' + score + '_' + mode+ '_' + filename, sep=',', header = True)
    elif mode == 'n3':
        results_n3 = runKmeans_pancancer_n3(data, score)
        results_n3.to_csv(path_results + '/' + score + '_' + mode + '_' + filename, sep=',', header = True)
    else:
        results_n2 = runKmeans_pancancer_n2(data, score)
        results_n3 = runKmeans_pancancer_n3(data, score)
        results = pd.merge(results_n2, results_n3, on=['Project ID','n_cases'])
        results.to_csv(path_results + '/' + score + '_' + filename + '.csv', sep=',', header = True)

# %%
HRD_pan_cancer = pd.read_csv('../../HRD_score/data/HRD_scores_pan_cancer_annotated_v2.csv', sep=',', header = 0)
primary = HRD_pan_cancer[HRD_pan_cancer['Type'] == 'Primary']

# %%
results_n2 = runKmeans_pancancer_n2(primary)
results_n3 = runKmeans_pancancer_n3(primary)

# %%
results = pd.merge(results_n2, results_n3, on=['Project ID','n_cases'])

# %%
results.to_csv('../data/kmeans_cutoffs_pancancer.csv', sep=',', header = True)

# %%
analyseStatistics(primary)
# Out:
# Empty DataFrame
# Columns: [Project ID, n2_silhouette, n3_silhouette, n4_silhouette, n5_silhouette, n6_silhouette, n2_inertia, n3_inertia, n4_inertia, n5_inertia, n6_inertia, n2_calinski, n3_calinski, n4_calinski, n5_calinski, n6_calinski, n2_davies, n3_davies, n4_davies, n5_davies, n6_davies]
# Index: []
#
# [0 rows x 21 columns]
# Finished analysis for n_comp = 2 for cohort TARGET-ALL-P2
# Finished analysis for n_comp = 3 for cohort TARGET-ALL-P2
# Finished analysis for n_comp = 4 for cohort TARGET-ALL-P2
# Finished analysis for n_comp = 5 for cohort TARGET-ALL-P2
# Finished analysis for n_comp = 6 for cohort TARGET-ALL-P2
# Finished cohort TARGET-ALL-P2
# Finished analysis for n_comp = 2 for cohort TARGET-AML
# Finished analysis for n_comp = 3 for cohort TARGET-AML
# Finished analysis for n_comp = 4 for cohort TARGET-AML
# Finished analysis for n_comp = 5 for cohort TARGET-AML
# Finished analysis for n_comp = 6 for cohort TARGET-AML
# Finished cohort TARGET-AML
# Finished analysis for n_comp = 2 for cohort TARGET-CCSK
# Finished analysis for n_comp = 3 for cohort TARGET-CCSK
# Finished analysis for n_comp = 4 for cohort TARGET-CCSK
# Finished analysis for n_comp = 5 for cohort TARGET-CCSK
# Finished analysis for n_comp = 6 for cohort TARGET-CCSK
# Finished cohort TARGET-CCSK
# Finished analysis for n_comp = 2 for cohort TARGET-OS
# Finished analysis for n_comp = 3 for cohort TARGET-OS
# Finished analysis for n_comp = 4 for cohort TARGET-OS
# Finished analysis for n_comp = 5 for cohort TARGET-OS
# Finished analysis for n_comp = 6 for cohort TARGET-OS
# Finished cohort TARGET-OS
# Finished analysis for n_comp = 2 for cohort TCGA-ACC
# Finished analysis for n_comp = 3 for cohort TCGA-ACC
# Finished analysis for n_comp = 4 for cohort TCGA-ACC
# Finished analysis for n_comp = 5 for cohort TCGA-ACC
# Finished analysis for n_comp = 6 for cohort TCGA-ACC
# Finished cohort TCGA-ACC
# Finished analysis for n_comp = 2 for cohort TCGA-BLCA
# Finished analysis for n_comp = 3 for cohort TCGA-BLCA
# Finished analysis for n_comp = 4 for cohort TCGA-BLCA
# Finished analysis for n_comp = 5 for cohort TCGA-BLCA
# Finished analysis for n_comp = 6 for cohort TCGA-BLCA
# Finished cohort TCGA-BLCA
# Finished analysis for n_comp = 2 for cohort TCGA-BRCA
# Finished analysis for n_comp = 3 for cohort TCGA-BRCA
# Finished analysis for n_comp = 4 for cohort TCGA-BRCA
# Finished analysis for n_comp = 5 for cohort TCGA-BRCA
# Finished analysis for n_comp = 6 for cohort TCGA-BRCA
# Finished cohort TCGA-BRCA
# Finished analysis for n_comp = 2 for cohort TCGA-CESC
# Finished analysis for n_comp = 3 for cohort TCGA-CESC
# Finished analysis for n_comp = 4 for cohort TCGA-CESC
# Finished analysis for n_comp = 5 for cohort TCGA-CESC
# Finished analysis for n_comp = 6 for cohort TCGA-CESC
# Finished cohort TCGA-CESC
# Finished analysis for n_comp = 2 for cohort TCGA-CHOL
# Finished analysis for n_comp = 3 for cohort TCGA-CHOL
# Finished analysis for n_comp = 4 for cohort TCGA-CHOL
# Finished analysis for n_comp = 5 for cohort TCGA-CHOL
# Finished analysis for n_comp = 6 for cohort TCGA-CHOL
# Finished cohort TCGA-CHOL
# Finished analysis for n_comp = 2 for cohort TCGA-COAD
# Finished analysis for n_comp = 3 for cohort TCGA-COAD
# Finished analysis for n_comp = 4 for cohort TCGA-COAD
# Finished analysis for n_comp = 5 for cohort TCGA-COAD
# Finished analysis for n_comp = 6 for cohort TCGA-COAD
# Finished cohort TCGA-COAD
# Finished analysis for n_comp = 2 for cohort TCGA-DLBC
# Finished analysis for n_comp = 3 for cohort TCGA-DLBC
# Finished analysis for n_comp = 4 for cohort TCGA-DLBC
# Finished analysis for n_comp = 5 for cohort TCGA-DLBC
# Finished analysis for n_comp = 6 for cohort TCGA-DLBC
# Finished cohort TCGA-DLBC
# Finished analysis for n_comp = 2 for cohort TCGA-ESCA
# Finished analysis for n_comp = 3 for cohort TCGA-ESCA
# Finished analysis for n_comp = 4 for cohort TCGA-ESCA
# Finished analysis for n_comp = 5 for cohort TCGA-ESCA
# Finished analysis for n_comp = 6 for cohort TCGA-ESCA
# Finished cohort TCGA-ESCA
# Finished analysis for n_comp = 2 for cohort TCGA-GBM
# Finished analysis for n_comp = 3 for cohort TCGA-GBM
# Finished analysis for n_comp = 4 for cohort TCGA-GBM
# Finished analysis for n_comp = 5 for cohort TCGA-GBM
# Finished analysis for n_comp = 6 for cohort TCGA-GBM
# Finished cohort TCGA-GBM
# Finished analysis for n_comp = 2 for cohort TCGA-HNSC
# Finished analysis for n_comp = 3 for cohort TCGA-HNSC
# Finished analysis for n_comp = 4 for cohort TCGA-HNSC
# Finished analysis for n_comp = 5 for cohort TCGA-HNSC
# Finished analysis for n_comp = 6 for cohort TCGA-HNSC
# Finished cohort TCGA-HNSC
# Finished analysis for n_comp = 2 for cohort TCGA-KICH
# Finished analysis for n_comp = 3 for cohort TCGA-KICH
# Finished analysis for n_comp = 4 for cohort TCGA-KICH
# Finished analysis for n_comp = 5 for cohort TCGA-KICH
# Finished analysis for n_comp = 6 for cohort TCGA-KICH
# Finished cohort TCGA-KICH
# Finished analysis for n_comp = 2 for cohort TCGA-KIRC
# Finished analysis for n_comp = 3 for cohort TCGA-KIRC
# Finished analysis for n_comp = 4 for cohort TCGA-KIRC
# Finished analysis for n_comp = 5 for cohort TCGA-KIRC
# Finished analysis for n_comp = 6 for cohort TCGA-KIRC
# Finished cohort TCGA-KIRC
# Finished analysis for n_comp = 2 for cohort TCGA-KIRP
# Finished analysis for n_comp = 3 for cohort TCGA-KIRP
# Finished analysis for n_comp = 4 for cohort TCGA-KIRP
# Finished analysis for n_comp = 5 for cohort TCGA-KIRP
# Finished analysis for n_comp = 6 for cohort TCGA-KIRP
# Finished cohort TCGA-KIRP
# Finished analysis for n_comp = 2 for cohort TCGA-LAML
# Finished analysis for n_comp = 3 for cohort TCGA-LAML
# Finished analysis for n_comp = 4 for cohort TCGA-LAML
# Finished analysis for n_comp = 5 for cohort TCGA-LAML
# Finished analysis for n_comp = 6 for cohort TCGA-LAML
# Finished cohort TCGA-LAML
# Finished analysis for n_comp = 2 for cohort TCGA-LGG
# Finished analysis for n_comp = 3 for cohort TCGA-LGG
# Finished analysis for n_comp = 4 for cohort TCGA-LGG
# Finished analysis for n_comp = 5 for cohort TCGA-LGG
# Finished analysis for n_comp = 6 for cohort TCGA-LGG
# Finished cohort TCGA-LGG
# Finished analysis for n_comp = 2 for cohort TCGA-LIHC
# Finished analysis for n_comp = 3 for cohort TCGA-LIHC
# Finished analysis for n_comp = 4 for cohort TCGA-LIHC
# Finished analysis for n_comp = 5 for cohort TCGA-LIHC
# Finished analysis for n_comp = 6 for cohort TCGA-LIHC
# Finished cohort TCGA-LIHC
# Finished analysis for n_comp = 2 for cohort TCGA-LUAD
# Finished analysis for n_comp = 3 for cohort TCGA-LUAD
# Finished analysis for n_comp = 4 for cohort TCGA-LUAD
# Finished analysis for n_comp = 5 for cohort TCGA-LUAD
# Finished analysis for n_comp = 6 for cohort TCGA-LUAD
# Finished cohort TCGA-LUAD
# Finished analysis for n_comp = 2 for cohort TCGA-LUSC
# Finished analysis for n_comp = 3 for cohort TCGA-LUSC
# Finished analysis for n_comp = 4 for cohort TCGA-LUSC
# Finished analysis for n_comp = 5 for cohort TCGA-LUSC
# Finished analysis for n_comp = 6 for cohort TCGA-LUSC
# Finished cohort TCGA-LUSC
# Finished analysis for n_comp = 2 for cohort TCGA-MESO
# Finished analysis for n_comp = 3 for cohort TCGA-MESO
# Finished analysis for n_comp = 4 for cohort TCGA-MESO
# Finished analysis for n_comp = 5 for cohort TCGA-MESO
# Finished analysis for n_comp = 6 for cohort TCGA-MESO
# Finished cohort TCGA-MESO
# Finished analysis for n_comp = 2 for cohort TCGA-OV
# Finished analysis for n_comp = 3 for cohort TCGA-OV
# Finished analysis for n_comp = 4 for cohort TCGA-OV
# Finished analysis for n_comp = 5 for cohort TCGA-OV
# Finished analysis for n_comp = 6 for cohort TCGA-OV
# Finished cohort TCGA-OV
# Finished analysis for n_comp = 2 for cohort TCGA-PAAD
# Finished analysis for n_comp = 3 for cohort TCGA-PAAD
# Finished analysis for n_comp = 4 for cohort TCGA-PAAD
# Finished analysis for n_comp = 5 for cohort TCGA-PAAD
# Finished analysis for n_comp = 6 for cohort TCGA-PAAD
# Finished cohort TCGA-PAAD
# Finished analysis for n_comp = 2 for cohort TCGA-PCPG
# Finished analysis for n_comp = 3 for cohort TCGA-PCPG
# Finished analysis for n_comp = 4 for cohort TCGA-PCPG
# Finished analysis for n_comp = 5 for cohort TCGA-PCPG
# Finished analysis for n_comp = 6 for cohort TCGA-PCPG
# Finished cohort TCGA-PCPG
# Finished analysis for n_comp = 2 for cohort TCGA-PRAD
# Finished analysis for n_comp = 3 for cohort TCGA-PRAD
# Finished analysis for n_comp = 4 for cohort TCGA-PRAD
# Finished analysis for n_comp = 5 for cohort TCGA-PRAD
# Finished analysis for n_comp = 6 for cohort TCGA-PRAD
# Finished cohort TCGA-PRAD
# Finished analysis for n_comp = 2 for cohort TCGA-READ
# Finished analysis for n_comp = 3 for cohort TCGA-READ
# Finished analysis for n_comp = 4 for cohort TCGA-READ
# Finished analysis for n_comp = 5 for cohort TCGA-READ
# Finished analysis for n_comp = 6 for cohort TCGA-READ
# Finished cohort TCGA-READ
# Finished analysis for n_comp = 2 for cohort TCGA-SARC
# Finished analysis for n_comp = 3 for cohort TCGA-SARC
# Finished analysis for n_comp = 4 for cohort TCGA-SARC
# Finished analysis for n_comp = 5 for cohort TCGA-SARC
# Finished analysis for n_comp = 6 for cohort TCGA-SARC
# Finished cohort TCGA-SARC
# Finished analysis for n_comp = 2 for cohort TCGA-SKCM
# Finished analysis for n_comp = 3 for cohort TCGA-SKCM
# Finished analysis for n_comp = 4 for cohort TCGA-SKCM
# Finished analysis for n_comp = 5 for cohort TCGA-SKCM
# Finished analysis for n_comp = 6 for cohort TCGA-SKCM
# Finished cohort TCGA-SKCM
# Finished analysis for n_comp = 2 for cohort TCGA-STAD
# Finished analysis for n_comp = 3 for cohort TCGA-STAD
# Finished analysis for n_comp = 4 for cohort TCGA-STAD
# Finished analysis for n_comp = 5 for cohort TCGA-STAD
# Finished analysis for n_comp = 6 for cohort TCGA-STAD
# Finished cohort TCGA-STAD
# Finished analysis for n_comp = 2 for cohort TCGA-TGCT
# Finished analysis for n_comp = 3 for cohort TCGA-TGCT
# Finished analysis for n_comp = 4 for cohort TCGA-TGCT
# Finished analysis for n_comp = 5 for cohort TCGA-TGCT
# Finished analysis for n_comp = 6 for cohort TCGA-TGCT
# Finished cohort TCGA-TGCT
# Finished analysis for n_comp = 2 for cohort TCGA-THCA
# Finished analysis for n_comp = 3 for cohort TCGA-THCA
# Finished analysis for n_comp = 4 for cohort TCGA-THCA
# Finished analysis for n_comp = 5 for cohort TCGA-THCA
# Finished analysis for n_comp = 6 for cohort TCGA-THCA
# Finished cohort TCGA-THCA
# Finished analysis for n_comp = 2 for cohort TCGA-THYM
# Finished analysis for n_comp = 3 for cohort TCGA-THYM
# Finished analysis for n_comp = 4 for cohort TCGA-THYM
# Finished analysis for n_comp = 5 for cohort TCGA-THYM
# Finished analysis for n_comp = 6 for cohort TCGA-THYM
# Finished cohort TCGA-THYM
# Finished analysis for n_comp = 2 for cohort TCGA-UCEC
# Finished analysis for n_comp = 3 for cohort TCGA-UCEC
# Finished analysis for n_comp = 4 for cohort TCGA-UCEC
# Finished analysis for n_comp = 5 for cohort TCGA-UCEC
# Finished analysis for n_comp = 6 for cohort TCGA-UCEC
# Finished cohort TCGA-UCEC
# Finished analysis for n_comp = 2 for cohort TCGA-UCS
# Finished analysis for n_comp = 3 for cohort TCGA-UCS
# Finished analysis for n_comp = 4 for cohort TCGA-UCS
# Finished analysis for n_comp = 5 for cohort TCGA-UCS
# Finished analysis for n_comp = 6 for cohort TCGA-UCS
# Finished cohort TCGA-UCS
# Finished analysis for n_comp = 2 for cohort TCGA-UVM
# Finished analysis for n_comp = 3 for cohort TCGA-UVM
# Finished analysis for n_comp = 4 for cohort TCGA-UVM
# Finished analysis for n_comp = 5 for cohort TCGA-UVM
# Finished analysis for n_comp = 6 for cohort TCGA-UVM
# Finished cohort TCGA-UVM
#        Project ID  n2_silhouette  n3_silhouette  n4_silhouette  n5_silhouette  \
# 0   TARGET-ALL-P2       0.623348       0.593944       0.663001       0.688384
# 1      TARGET-AML       0.899806       0.760432       0.753573       0.750000
# 2     TARGET-CCSK       0.520960       0.591486       0.631818       0.681818
# 3       TARGET-OS       0.561321       0.534790       0.582138       0.557661
# 4        TCGA-ACC       0.583560       0.648230       0.595537       0.598910
# 5       TCGA-BLCA       0.595380       0.587023       0.576744       0.554251
# 6       TCGA-BRCA       0.625439       0.599230       0.576598       0.554939
# 7       TCGA-CESC       0.607730       0.519853       0.562866       0.549177
# 8       TCGA-CHOL       0.646565       0.587959       0.613250       0.664733
# 9       TCGA-COAD       0.593490       0.598273       0.592416       0.599890
# 10      TCGA-DLBC       0.705957       0.620234       0.589125       0.600130
# 11      TCGA-ESCA       0.525639       0.574426       0.534922       0.569271
# 12       TCGA-GBM       0.638984       0.594098       0.552604       0.539051
# 13      TCGA-HNSC       0.564599       0.541720       0.528192       0.553026
# 14      TCGA-KICH       0.693790       0.685340       0.701487       0.710385
# 15      TCGA-KIRC       0.655231       0.597994       0.562952       0.549664
# 16      TCGA-KIRP       0.740015       0.715630       0.640747       0.652708
# 17      TCGA-LAML       0.827040       0.751388       0.732112       0.721316
# 18       TCGA-LGG       0.647240       0.594685       0.567859       0.579570
# 19      TCGA-LIHC       0.577032       0.565948       0.564384       0.544251
# 20      TCGA-LUAD       0.597368       0.545588       0.551203       0.574143
# 21      TCGA-LUSC       0.517950       0.518153       0.542507       0.547392
# 22      TCGA-MESO       0.623688       0.535900       0.505138       0.577723
# 23        TCGA-OV       0.582549       0.551466       0.530379       0.545017
# 24      TCGA-PAAD       0.620310       0.604374       0.670922       0.662711
# 25      TCGA-PCPG       0.676332       0.614237       0.578596       0.578687
# 26      TCGA-PRAD       0.595271       0.573236       0.570844       0.578792
# 27      TCGA-READ       0.537713       0.541805       0.546874       0.588749
# 28      TCGA-SARC       0.594536       0.559008       0.578243       0.582883
# 29      TCGA-SKCM       0.644006       0.549180       0.612602       0.615007
# 30      TCGA-STAD       0.646933       0.602054       0.600216       0.584020
# 31      TCGA-TGCT       0.562905       0.553716       0.534978       0.545323
# 32      TCGA-THCA       0.849369       0.792191       0.773640       0.775480
# 33      TCGA-THYM       0.751145       0.767729       0.774504       0.779745
# 34      TCGA-UCEC       0.785206       0.767655       0.746063       0.632031
# 35       TCGA-UCS       0.646794       0.540305       0.542232       0.619674
# 36       TCGA-UVM       0.662951       0.622687       0.624513       0.637721
#
#     n6_silhouette     n2_inertia    n3_inertia    n4_inertia    n5_inertia  \
# 0        0.705436     942.302952    518.453612    264.577302    165.374619
# 1        0.757173     401.757576    175.892241     77.892241     26.305769
# 2        0.727273      12.000000      3.950000      1.416667      0.666667
# 3        0.552139    6720.200000   3738.523932   1970.119596   1276.348293
# 4        0.560248    7650.413793   2663.805556   1809.473333   1192.940000
# 5        0.579510   44579.408069  21273.617693  12164.876166   8031.933948
# 6        0.548625  154023.627311  66484.389812  39140.671164  25450.594704
# 7        0.524295   17719.389583  10295.256762   5336.754899   3598.118013
# 8        0.679788     960.857143    439.444444    221.064528    106.241667
# 9        0.596876   23128.705646  11355.109666   6946.503266   4364.344182
# 10       0.641121    2646.846512    865.386364    528.541026    344.974359
# 11       0.560447   19865.637981   8785.612813   5285.973588   3215.563500
# 12       0.555733   14407.777205   7196.804159   3883.442415   2594.426110
# 13       0.547786   42103.549925  21226.239966  12996.341316   8164.138072
# 14       0.722868    2769.345455    997.738095    529.181090    274.308333
# 15       0.530057   14713.427694   7658.186130   4929.247865   3301.428122
# 16       0.659140    5860.431995   2363.399643   1483.614194    950.607586
# 17       0.727158     970.053020    419.212388    239.217984    138.082686
# 18       0.595241   13452.960579   6359.712782   3784.182788   2403.137286
# 19       0.554917   20992.158439  10164.949727   6147.373426   4402.818066
# 20       0.572179   47605.850649  24561.862828  14493.610165   9162.358509
# 21       0.526236   56986.060181  30109.903910  16741.592801  10378.904050
# 22       0.580319    5951.282264   3096.353439   1791.924183    940.057143
# 23       0.535047   72877.326393  37755.429837  22637.934493  14265.209097
# 24       0.685016   13600.320469   7041.750000   3351.137826   2232.564784
# 25       0.579135    4797.849436   2199.640921   1247.731500    806.898167
# 26       0.571538   24850.211801  11506.317247   6572.779839   4192.862028
# 27       0.556930   10503.103535   4961.283810   2938.030412   1592.818400
# 28       0.579555   32309.694489  15467.201539   8622.909996   5387.316199
# 29       0.595898    4828.871795   2731.837957   1271.636310    899.612500
# 30       0.559910   51510.124571  24630.539925  14092.035961   9576.822744
# 31       0.560969    5615.631622   2709.902020   1634.541005   1086.539139
# 32       0.775612    1883.522388    822.143431    488.755439    295.649827
# 33       0.780410    1780.180583    687.221027    346.249179    215.582512
# 34       0.636555   38245.582088  17145.989888   9912.992014   7123.757249
# 35       0.614738    3329.549123   1738.061111   1063.986869    533.144643
# 36       0.669147     657.843422    341.138725    167.434211    111.359368
#
#     ...  n2_calinski  n3_calinski  n4_calinski  n5_calinski  n6_calinski  \
# 0   ...   600.343261   662.236230   954.579155  1184.626422  1640.962253
# 1   ...   209.088630   276.906518   437.291216   986.837607  1510.930368
# 2   ...    17.181818    31.350978    55.163993    77.045455     1.000000
# 3   ...   127.639981   144.372372   203.339058   242.669955   246.085697
# 4   ...   130.327374   266.453955   272.034737   316.854366   448.924921
# 5   ...   825.288511  1075.015602  1346.667797  1575.413356  1920.832659
# 6   ...  2667.422871  3791.337500  4538.235981  5373.266537  6211.836601
# 7   ...   578.872425   603.203658   864.512300   993.943991  1056.829226
# 8   ...    75.937490   100.155626   139.244984   218.887906   279.144678
# 9   ...   809.494694  1042.284786  1222.654955  1518.496517  1880.154177
# 10  ...    78.857401   164.291748   184.693291   213.125652   312.332170
# 11  ...   284.484949   433.359407   517.015303   662.521313   754.483715
# 12  ...   853.856308  1101.465378  1498.860168  1740.626592  1911.570106
# 13  ...   998.636582  1240.289535  1455.691896  1810.030674  1973.649979
# 14  ...   111.004443   207.578341   275.074888   405.745134   476.184382
# 15  ...   810.146008   991.706921  1110.954631  1298.695100  1481.405900
# 16  ...   521.375427   841.540240   942.948793  1136.742850  1528.494402
# 17  ...   445.518231   635.578420   785.216888  1048.636881  1226.077473
# 18  ...   976.240508  1312.685418  1582.398004  1937.542659  2182.552628
# 19  ...   700.377361   915.606748  1085.861756  1169.924071  1413.626128
# 20  ...  1157.912634  1352.550538  1639.622554  2013.176085  2242.337057
# 21  ...   662.530711   834.934621  1123.524440  1427.886006  1545.305777
# 22  ...   173.810323   203.309989   251.281691   373.211587   469.232197
# 23  ...  1158.760817  1373.542394  1647.303857  2037.919140  2319.737439
# 24  ...   390.103913   457.508709   702.285231   808.189717  1155.622033
# 25  ...   228.082971   342.897783   441.454392   530.649156   650.799941
# 26  ...   829.728678  1176.534487  1491.873161  1819.222293  2207.647840
# 27  ...   250.297351   352.656865   431.024412   625.893440   723.349695
# 28  ...   574.604568   729.439675   932.438984  1150.733812  1400.927673
# 29  ...   202.434281   215.524143   343.478315   370.593195   505.715619
# 30  ...  1338.576121  1632.733420  2005.792356  2259.279087  2402.638686
# 31  ...   306.732791   397.780052   470.112408   545.961962   613.167889
# 32  ...   903.613387  1352.517785  1625.985730  2092.427243  2339.328440
# 33  ...   220.928753   379.206868   536.636845   658.871370  1272.225337
# 34  ...  2400.576066  3000.281138  3582.520922  3783.864317  4496.124435
# 35  ...   123.881812   139.223333   158.932981   244.978087   285.919522
# 36  ...   170.223239   197.765375   291.418043   333.738446   542.218081
#
#     n2_davies  n3_davies  n4_davies  n5_davies  n6_davies
# 0    0.548829   0.554489   0.454316   0.457863   0.422265
# 1    0.336955   0.388936   0.218311   0.274342   0.280967
# 2    0.619048   0.512045   0.354010   0.231429   0.000000
# 3    0.604244   0.557685   0.504498   0.501876   0.422759
# 4    0.624738   0.448023   0.512863   0.415149   0.456644
# 5    0.547042   0.512920   0.505659   0.522908   0.474808
# 6    0.529391   0.495137   0.506014   0.519384   0.514757
# 7    0.557901   0.578985   0.500986   0.518374   0.531675
# 8    0.526648   0.517420   0.411729   0.383083   0.378976
# 9    0.577391   0.506081   0.494812   0.452149   0.459455
# 10   0.451010   0.415962   0.452695   0.464717   0.401147
# 11   0.652565   0.519081   0.539012   0.480214   0.480534
# 12   0.576990   0.521085   0.514697   0.505058   0.523077
# 13   0.581572   0.553503   0.550162   0.531738   0.507415
# 14   0.591176   0.456524   0.454000   0.321481   0.260724
# 15   0.558715   0.544386   0.554791   0.560499   0.551073
# 16   0.548443   0.452850   0.498449   0.468150   0.458226
# 17   0.412385   0.474532   0.469880   0.471737   0.438450
# 18   0.561637   0.533552   0.515951   0.493795   0.482533
# 19   0.578012   0.533378   0.523942   0.547814   0.503733
# 20   0.533571   0.557564   0.533664   0.497208   0.505520
# 21   0.658091   0.589798   0.520612   0.495320   0.510572
# 22   0.550677   0.564728   0.566421   0.439767   0.449560
# 23   0.559264   0.556260   0.562803   0.525247   0.509247
# 24   0.524002   0.562648   0.480527   0.439439   0.444645
# 25   0.621327   0.503084   0.511742   0.415099   0.426302
# 26   0.602158   0.537980   0.512272   0.497230   0.494310
# 27   0.646926   0.555807   0.522851   0.445231   0.462697
# 28   0.548966   0.527517   0.490134   0.479587   0.480569
# 29   0.543592   0.535671   0.448655   0.342475   0.381660
# 30   0.465735   0.525126   0.508172   0.506222   0.517118
# 31   0.584212   0.527506   0.535358   0.532656   0.493885
# 32   0.506864   0.485899   0.487533   0.486510   0.488104
# 33   0.531636   0.435046   0.429567   0.276365   0.299488
# 34   0.351758   0.483067   0.447023   0.533119   0.502386
# 35   0.474882   0.555403   0.533278   0.394031   0.428352
# 36   0.516238   0.497595   0.466315   0.434346   0.345718
#
# [37 rows x 21 columns]

# %% [markdown]
# # Run K-means cutoff

# %%
runKmeansCutoff(mode = 'both', path_data_file = '../../HRD_score/data/HRD_scores_pan_cancer_annotated_v2.csv', path_results = '../data', score = 'TAI', filename = 'kmeans_cutoff_pancancer')
